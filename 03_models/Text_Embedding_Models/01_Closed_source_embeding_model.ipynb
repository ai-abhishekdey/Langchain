# %% [markdown]
# ### Load OpenAI API Key

# %%
import os
from dotenv import load_dotenv

OPENAI_API_KEY=os.getenv("OPENAI_API_KEY")

# %% [markdown]
# ### Load OpenAI text-embedding-3-small model

# %%
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
    dimensions=32
)

# %% [markdown]
# ### Get Text embeddings of a single query

# %%
query="New Delhi is the capital of India"

embedding_vector=embeddings.embed_query(query)

# %%
print(embedding_vector)
# Out:
# [0.14761805534362793, 0.09963373094797134, 0.21178512275218964, 0.03290112316608429, -0.2970404624938965, 0.11463236063718796, -0.020876847207546234, 0.2252049446105957, -0.05094458535313606, -0.027826398611068726, 0.12878520786762238, 0.27313289046287537, -0.2073870301246643, -0.03295750916004181, 0.09523563832044601, -0.22159625589847565, -0.30155134201049805, 0.1463775783777237, 0.1788558065891266, 0.16069957613945007, 0.37485289573669434, 0.10589256137609482, 0.16024848818778992, 0.09771661460399628, 0.32793989777565, 0.2042294144630432, -0.0704822689294815, -0.03388787433505058, 0.19859084486961365, 0.08023701608181, -0.11181306838989258, -0.04598263278603554]

# %%
print("Dimension of embedding vector : ", len(embedding_vector))
# Out:
# Dimension of embedding vector :  32

# %% [markdown]
# ### Documents

# %%
documents=[
    "Kolkata is the capital of West Bengal",
    "Dispur is the capital of Assam",
    "Mumbai is the capital of Maharastra",
    "Chennai is the capital of Tamil Nadu",
    "Kohima is the capital of Nagaland"
]

# %% [markdown]
# ### Get Text embeddings of a documents

# %%
embedding_vector_docs=embeddings.embed_documents(documents)

# %%
print(embedding_vector_docs)
# Out:
# [[0.14857883751392365, -0.12422165274620056, 0.33759060502052307, 0.09834214299917221, -0.38849711418151855, 0.12330825626850128, -0.04469543695449829, 0.1567384898662567, -0.13067631423473358, 0.04560883343219757, 0.09992536157369614, -0.05401206016540527, -0.17098745703697205, 0.009864660911262035, -0.07276709377765656, -0.2056964486837387, -0.11216484755277634, 0.181095689535141, -0.07221905887126923, -0.005396638996899128, 0.3431927561759949, -0.292529821395874, -0.0884774774312973, -0.02213459275662899, 0.23175862431526184, 0.3483077585697174, -0.1756153106689453, -0.04819678142666817, 0.216778963804245, 0.04414740204811096, -0.0512414313852787, -0.12288200855255127], [0.31988927721977234, -0.1525825709104538, 0.33836662769317627, 0.13331125676631927, -0.26691120862960815, 0.09079889953136444, -0.2007969170808792, 0.24785645306110382, -0.09339727461338043, -0.2316887527704239, 0.16788412630558014, 0.1300632804632187,